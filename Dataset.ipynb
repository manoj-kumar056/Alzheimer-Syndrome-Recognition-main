# %% [markdown]
# ### Uploading json token

# %% [markdown]
# ### Downloading Zip File of Dataset

# %%
# !kaggle datasets download -d tourist55/alzheimers-dataset-4-class-of-images
# Out:
# 'kaggle' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from zipfile import ZipFile
file_name = ('D:/Alzhimer/AD/Alzheimers-Disease-Classification')
with ZipFile(file_name,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[4], line 3
#       1 from zipfile import ZipFile
#       2 file_name = ('D:/Alzhimer/AD/Alzheimers-Disease-Classification')
# ----> 3 with ZipFile(file_name,'r') as zip:
#       4   zip.extractall()
#       5   print('Done')
#
# File c:\Users\manik\AppData\Local\Programs\Python\Python312\Lib\zipfile\__init__.py:1331, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1329 while True:
#    1330     try:
# -> 1331         self.fp = io.open(file, filemode)
#    1332     except OSError:
#    1333         if filemode in modeDict:
#
# PermissionError: [Errno 13] Permission denied: 'D:/Alzhimer/AD/Alzheimers-Disease-Classification'
